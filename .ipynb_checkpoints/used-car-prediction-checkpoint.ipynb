# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./used_car_dataset.csv")
df
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9582 rows x 11 columns]

# %%
df.shape
# Out:
# (9582, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9582 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9582 non-null   object
#  1   model         9582 non-null   object
#  2   Year          9582 non-null   int64
#  3   Age           9582 non-null   int64
#  4   kmDriven      9535 non-null   object
#  5   Transmission  9582 non-null   object
#  6   Owner         9582 non-null   object
#  7   FuelType      9582 non-null   object
#  8   PostedDate    9582 non-null   object
#  9   AdditionInfo  9582 non-null   object
#  10  AskPrice      9582 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 823.6+ KB

# %%
df.isnull().sum()
# Out:
# Brand            0
# model            0
# Year             0
# Age              0
# kmDriven        47
# Transmission     0
# Owner            0
# FuelType         0
# PostedDate       0
# AdditionInfo     0
# AskPrice         0
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# Brand           0
# model           0
# Year            0
# Age             0
# kmDriven        0
# Transmission    0
# Owner           0
# FuelType        0
# PostedDate      0
# AdditionInfo    0
# AskPrice        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Brand           0
# model           0
# Year            0
# Age             0
# kmDriven        0
# Transmission    0
# Owner           0
# FuelType        0
# PostedDate      0
# AdditionInfo    0
# AskPrice        0
# dtype: int64

# %%
df.describe()
# Out:
#               Year          Age
# count  9535.000000  9535.000000
# mean   2016.375669     7.624331
# std       4.071090     4.071090
# min    1986.000000     0.000000
# 25%    2014.000000     5.000000
# 50%    2017.000000     7.000000
# 75%    2019.000000    10.000000
# max    2024.000000    38.000000

# %%
df1= df[['Brand','model','Year','Age','kmDriven','Transmission','Owner','FuelType','PostedDate','AdditionInfo','AskPrice']]

# %%
df1
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
df1 = df1.rename(columns={'model': 'Model','kmDriven':'KmDriven'})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9535 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9535 non-null   object
#  1   Model         9535 non-null   object
#  2   Year          9535 non-null   int64
#  3   Age           9535 non-null   int64
#  4   KmDriven      9535 non-null   object
#  5   Transmission  9535 non-null   object
#  6   Owner         9535 non-null   object
#  7   FuelType      9535 non-null   object
#  8   PostedDate    9535 non-null   object
#  9   AdditionInfo  9535 non-null   object
#  10  AskPrice      9535 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 893.9+ KB

# %%
df1['KmDriven'] = df1['KmDriven'].str.replace(' km', '', regex=False)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000       Manual  second
# 1            Toyota     Innova  2009   15  190000.0       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000       Manual  second
# 1            Toyota     Innova  2009   15  190000.0       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
df1['KmDriven'] = df1['KmDriven'].str.replace(',', '', regex=False)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15  190000.0       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9535 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9535 non-null   object
#  1   Model         9535 non-null   object
#  2   Year          9535 non-null   int64
#  3   Age           9535 non-null   int64
#  4   KmDriven      9535 non-null   object
#  5   Transmission  9535 non-null   object
#  6   Owner         9535 non-null   object
#  7   FuelType      9535 non-null   object
#  8   PostedDate    9535 non-null   object
#  9   AdditionInfo  9535 non-null   object
#  10  AskPrice      9535 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 893.9+ KB

# %%
df1['KmDriven'] = pd. to_numeric(df1['KmDriven'], downcast='integer', errors='coerce')
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
unique_brands = df['Brand'].unique()
print(unique_brands)
# Out:
# ['Honda' 'Toyota' 'Volkswagen' 'Maruti Suzuki' 'BMW' 'Ford' 'Kia'
#  'Mercedes-Benz' 'Hyundai' 'Audi' 'Renault' 'MG' 'Volvo' 'Skoda' 'Tata'
#  'Mahindra' 'Mini' 'Land Rover' 'Jeep' 'Chevrolet' 'Jaguar' 'Fiat'
#  'Aston Martin' 'Porsche' 'Nissan' 'Force' 'Mitsubishi' 'Lexus' 'Isuzu'
#  'Datsun' 'Ambassador' 'Rolls-Royce' 'Bajaj' 'Opel' 'Ashok' 'Bentley'
#  'Ssangyong' 'Maserati']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9535 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9535 non-null   object
#  1   Model         9535 non-null   object
#  2   Year          9535 non-null   int64
#  3   Age           9535 non-null   int64
#  4   KmDriven      9535 non-null   int32
#  5   Transmission  9535 non-null   object
#  6   Owner         9535 non-null   object
#  7   FuelType      9535 non-null   object
#  8   PostedDate    9535 non-null   object
#  9   AdditionInfo  9535 non-null   object
#  10  AskPrice      9535 non-null   object
# dtypes: int32(1), int64(2), object(8)
# memory usage: 856.7+ KB

# %%
df1['KmDriven'] = df1['KmDriven'].astype(int)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [9535 rows x 11 columns]

# %%
df1['AskPrice']=df1['AskPrice'].str.replace('₹','',regex=False)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo    AskPrice
# 0     Honda City v teck in mint condition, valid gen...    1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    6,85,000
# ...                                                 ...         ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    6,99,000
#
# [9535 rows x 11 columns]

# %%
df1['AskPrice']=df1['AskPrice'].str.replace(',','',regex=False)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo  AskPrice
# 0     Honda City v teck in mint condition, valid gen...    195000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    375000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    184999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    565000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    685000
# ...                                                 ...       ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   1040000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    375000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    415000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    855000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    699000
#
# [9535 rows x 11 columns]

# %%
df1['AskPrice']=pd.to_numeric(df1['AskPrice'],downcast='integer',errors='coerce')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9535 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9535 non-null   object
#  1   Model         9535 non-null   object
#  2   Year          9535 non-null   int64
#  3   Age           9535 non-null   int64
#  4   KmDriven      9535 non-null   int32
#  5   Transmission  9535 non-null   object
#  6   Owner         9535 non-null   object
#  7   FuelType      9535 non-null   object
#  8   PostedDate    9535 non-null   object
#  9   AdditionInfo  9535 non-null   object
#  10  AskPrice      9535 non-null   int32
# dtypes: int32(2), int64(2), object(7)
# memory usage: 819.4+ KB

# %%
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo  AskPrice
# 0     Honda City v teck in mint condition, valid gen...    195000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    375000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    184999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    565000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    685000
# ...                                                 ...       ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   1040000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    375000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    415000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    855000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    699000
#
# [9535 rows x 11 columns]

# %%
TransmissionType=pd.get_dummies(df1['Transmission'],drop_first=True)
TransmissionType
# Out:
#       Manual
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
# ...      ...
# 9577   False
# 9578    True
# 9579    True
# 9580   False
# 9581    True
#
# [9535 rows x 1 columns]

# %%
df1=pd.concat([df1,TransmissionType],axis=1)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo  AskPrice  Manual
# 0     Honda City v teck in mint condition, valid gen...    195000    True
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    375000    True
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    184999    True
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    565000    True
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    685000   False
# ...                                                 ...       ...     ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   1040000   False
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    375000    True
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    415000    True
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    855000   False
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    699000    True
#
# [9535 rows x 12 columns]

# %%
owner=pd.get_dummies(df1['Owner'],drop_first=True)
owner
# Out:
#       second
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
# ...      ...
# 9577    True
# 9578   False
# 9579   False
# 9580   False
# 9581    True
#
# [9535 rows x 1 columns]

# %%
fuelType=pd.get_dummies(df1['FuelType'],drop_first=False)
fuelType
# Out:
#       Diesel  Hybrid/CNG  Petrol
# 0      False       False    True
# 1       True       False   False
# 2       True       False   False
# 3       True       False   False
# 4      False       False    True
# ...      ...         ...     ...
# 9577    True       False   False
# 9578   False        True   False
# 9579    True       False   False
# 9580   False       False    True
# 9581   False       False    True
#
# [9535 rows x 3 columns]

# %%
df1=pd.concat([df1,owner],axis=1)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo  AskPrice  Manual  \
# 0     Honda City v teck in mint condition, valid gen...    195000    True
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    375000    True
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    184999    True
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    565000    True
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    685000   False
# ...                                                 ...       ...     ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   1040000   False
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    375000    True
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    415000    True
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    855000   False
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    699000    True
#
#       second
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
# ...      ...
# 9577    True
# 9578   False
# 9579   False
# 9580   False
# 9581    True
#
# [9535 rows x 13 columns]

# %%
df1=pd.concat([df1,fuelType],axis=1)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven Transmission   Owner  \
# 0             Honda       City  2001   23     98000       Manual  second
# 1            Toyota     Innova  2009   15    190000       Manual  second
# 2        Volkswagen  VentoTest  2010   14     77246       Manual   first
# 3     Maruti Suzuki      Swift  2017    7     83500       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5     45000    Automatic   first
# ...             ...        ...   ...  ...       ...          ...     ...
# 9577          Skoda    Octavia  2014   10    105904    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4     55000       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11     92000       Manual   first
# 9580        Hyundai      Verna  2019    5     72000    Automatic   first
# 9581        Hyundai    New i20  2021    3     83228       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo  AskPrice  Manual  \
# 0     Honda City v teck in mint condition, valid gen...    195000    True
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    375000    True
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    184999    True
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    565000    True
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    685000   False
# ...                                                 ...       ...     ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   1040000   False
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    375000    True
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    415000    True
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    855000   False
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    699000    True
#
#       second  Diesel  Hybrid/CNG  Petrol
# 0       True   False       False    True
# 1       True    True       False   False
# 2      False    True       False   False
# 3       True    True       False   False
# 4      False   False       False    True
# ...      ...     ...         ...     ...
# 9577    True    True       False   False
# 9578   False   False        True   False
# 9579   False    True       False   False
# 9580   False   False       False    True
# 9581    True   False       False    True
#
# [9535 rows x 16 columns]

# %%
df1 = df1.drop(['Transmission','Owner','FuelType'],axis = 1)
df1
# Out:
#               Brand      Model  Year  Age  KmDriven PostedDate  \
# 0             Honda       City  2001   23     98000     Nov-24
# 1            Toyota     Innova  2009   15    190000     Jul-24
# 2        Volkswagen  VentoTest  2010   14     77246     Nov-24
# 3     Maruti Suzuki      Swift  2017    7     83500     Nov-24
# 4     Maruti Suzuki     Baleno  2019    5     45000     Nov-24
# ...             ...        ...   ...  ...       ...        ...
# 9577          Skoda    Octavia  2014   10    105904     Oct-24
# 9578  Maruti Suzuki   Alto-800  2020    4     55000     Nov-24
# 9579  Maruti Suzuki       Ritz  2013   11     92000     Nov-24
# 9580        Hyundai      Verna  2019    5     72000     Oct-24
# 9581        Hyundai    New i20  2021    3     83228     Nov-24
#
#                                            AdditionInfo  AskPrice  Manual  \
# 0     Honda City v teck in mint condition, valid gen...    195000    True
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...    375000    True
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...    184999    True
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition    565000    True
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol    685000   False
# ...                                                 ...       ...     ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel   1040000   False
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...    375000    True
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel    415000    True
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol    855000   False
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol    699000    True
#
#       second  Diesel  Hybrid/CNG  Petrol
# 0       True   False       False    True
# 1       True    True       False   False
# 2      False    True       False   False
# 3       True    True       False   False
# 4      False   False       False    True
# ...      ...     ...         ...     ...
# 9577    True    True       False   False
# 9578   False   False        True   False
# 9579   False    True       False   False
# 9580   False   False       False    True
# 9581    True   False       False    True
#
# [9535 rows x 13 columns]

# %%
df1 = df1.drop(['Model','PostedDate','AdditionInfo'],axis = 1)
df1
# Out:
#               Brand  Year  Age  KmDriven  AskPrice  Manual  second  Diesel  \
# 0             Honda  2001   23     98000    195000    True    True   False
# 1            Toyota  2009   15    190000    375000    True    True    True
# 2        Volkswagen  2010   14     77246    184999    True   False    True
# 3     Maruti Suzuki  2017    7     83500    565000    True    True    True
# 4     Maruti Suzuki  2019    5     45000    685000   False   False   False
# ...             ...   ...  ...       ...       ...     ...     ...     ...
# 9577          Skoda  2014   10    105904   1040000   False    True    True
# 9578  Maruti Suzuki  2020    4     55000    375000    True   False   False
# 9579  Maruti Suzuki  2013   11     92000    415000    True   False    True
# 9580        Hyundai  2019    5     72000    855000   False   False   False
# 9581        Hyundai  2021    3     83228    699000    True    True   False
#
#       Hybrid/CNG  Petrol
# 0          False    True
# 1          False   False
# 2          False   False
# 3          False   False
# 4          False    True
# ...          ...     ...
# 9577       False   False
# 9578        True   False
# 9579       False   False
# 9580       False    True
# 9581       False    True
#
# [9535 rows x 10 columns]

# %%
df1 = df1.drop(['Year'],axis = 1)
df1
# Out:
#               Brand  Age  KmDriven  AskPrice  Manual  second  Diesel  \
# 0             Honda   23     98000    195000    True    True   False
# 1            Toyota   15    190000    375000    True    True    True
# 2        Volkswagen   14     77246    184999    True   False    True
# 3     Maruti Suzuki    7     83500    565000    True    True    True
# 4     Maruti Suzuki    5     45000    685000   False   False   False
# ...             ...  ...       ...       ...     ...     ...     ...
# 9577          Skoda   10    105904   1040000   False    True    True
# 9578  Maruti Suzuki    4     55000    375000    True   False   False
# 9579  Maruti Suzuki   11     92000    415000    True   False    True
# 9580        Hyundai    5     72000    855000   False   False   False
# 9581        Hyundai    3     83228    699000    True    True   False
#
#       Hybrid/CNG  Petrol
# 0          False    True
# 1          False   False
# 2          False   False
# 3          False   False
# 4          False    True
# ...          ...     ...
# 9577       False   False
# 9578        True   False
# 9579       False   False
# 9580       False    True
# 9581       False    True
#
# [9535 rows x 9 columns]

# %%
BrandName=pd.get_dummies(df1['Brand'],drop_first=False)
BrandName
# Out:
#       Ambassador  Ashok  Aston Martin   Audi    BMW  Bajaj  Bentley  \
# 0          False  False         False  False  False  False    False
# 1          False  False         False  False  False  False    False
# 2          False  False         False  False  False  False    False
# 3          False  False         False  False  False  False    False
# 4          False  False         False  False  False  False    False
# ...          ...    ...           ...    ...    ...    ...      ...
# 9577       False  False         False  False  False  False    False
# 9578       False  False         False  False  False  False    False
# 9579       False  False         False  False  False  False    False
# 9580       False  False         False  False  False  False    False
# 9581       False  False         False  False  False  False    False
#
#       Chevrolet  Datsun   Fiat  ...   Opel  Porsche  Renault  Rolls-Royce  \
# 0         False   False  False  ...  False    False    False        False
# 1         False   False  False  ...  False    False    False        False
# 2         False   False  False  ...  False    False    False        False
# 3         False   False  False  ...  False    False    False        False
# 4         False   False  False  ...  False    False    False        False
# ...         ...     ...    ...  ...    ...      ...      ...          ...
# 9577      False   False  False  ...  False    False    False        False
# 9578      False   False  False  ...  False    False    False        False
# 9579      False   False  False  ...  False    False    False        False
# 9580      False   False  False  ...  False    False    False        False
# 9581      False   False  False  ...  False    False    False        False
#
#       Skoda  Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 0     False      False  False   False       False  False
# 1     False      False  False    True       False  False
# 2     False      False  False   False        True  False
# 3     False      False  False   False       False  False
# 4     False      False  False   False       False  False
# ...     ...        ...    ...     ...         ...    ...
# 9577   True      False  False   False       False  False
# 9578  False      False  False   False       False  False
# 9579  False      False  False   False       False  False
# 9580  False      False  False   False       False  False
# 9581  False      False  False   False       False  False
#
# [9535 rows x 38 columns]

# %%
df1=pd.concat([df1,BrandName],axis=1)
df1
# Out:
#               Brand  Age  KmDriven  AskPrice  Manual  second  Diesel  \
# 0             Honda   23     98000    195000    True    True   False
# 1            Toyota   15    190000    375000    True    True    True
# 2        Volkswagen   14     77246    184999    True   False    True
# 3     Maruti Suzuki    7     83500    565000    True    True    True
# 4     Maruti Suzuki    5     45000    685000   False   False   False
# ...             ...  ...       ...       ...     ...     ...     ...
# 9577          Skoda   10    105904   1040000   False    True    True
# 9578  Maruti Suzuki    4     55000    375000    True   False   False
# 9579  Maruti Suzuki   11     92000    415000    True   False    True
# 9580        Hyundai    5     72000    855000   False   False   False
# 9581        Hyundai    3     83228    699000    True    True   False
#
#       Hybrid/CNG  Petrol  Ambassador  ...   Opel  Porsche  Renault  \
# 0          False    True       False  ...  False    False    False
# 1          False   False       False  ...  False    False    False
# 2          False   False       False  ...  False    False    False
# 3          False   False       False  ...  False    False    False
# 4          False    True       False  ...  False    False    False
# ...          ...     ...         ...  ...    ...      ...      ...
# 9577       False   False       False  ...  False    False    False
# 9578        True   False       False  ...  False    False    False
# 9579       False   False       False  ...  False    False    False
# 9580       False    True       False  ...  False    False    False
# 9581       False    True       False  ...  False    False    False
#
#       Rolls-Royce  Skoda  Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 0           False  False      False  False   False       False  False
# 1           False  False      False  False    True       False  False
# 2           False  False      False  False   False        True  False
# 3           False  False      False  False   False       False  False
# 4           False  False      False  False   False       False  False
# ...           ...    ...        ...    ...     ...         ...    ...
# 9577        False   True      False  False   False       False  False
# 9578        False  False      False  False   False       False  False
# 9579        False  False      False  False   False       False  False
# 9580        False  False      False  False   False       False  False
# 9581        False  False      False  False   False       False  False
#
# [9535 rows x 47 columns]

# %%
df1=df1.drop(['Brand'],axis=1)
df1
# Out:
#       Age  KmDriven  AskPrice  Manual  second  Diesel  Hybrid/CNG  Petrol  \
# 0      23     98000    195000    True    True   False       False    True
# 1      15    190000    375000    True    True    True       False   False
# 2      14     77246    184999    True   False    True       False   False
# 3       7     83500    565000    True    True    True       False   False
# 4       5     45000    685000   False   False   False       False    True
# ...   ...       ...       ...     ...     ...     ...         ...     ...
# 9577   10    105904   1040000   False    True    True       False   False
# 9578    4     55000    375000    True   False   False        True   False
# 9579   11     92000    415000    True   False    True       False   False
# 9580    5     72000    855000   False   False   False       False    True
# 9581    3     83228    699000    True    True   False       False    True
#
#       Ambassador  Ashok  ...   Opel  Porsche  Renault  Rolls-Royce  Skoda  \
# 0          False  False  ...  False    False    False        False  False
# 1          False  False  ...  False    False    False        False  False
# 2          False  False  ...  False    False    False        False  False
# 3          False  False  ...  False    False    False        False  False
# 4          False  False  ...  False    False    False        False  False
# ...          ...    ...  ...    ...      ...      ...          ...    ...
# 9577       False  False  ...  False    False    False        False   True
# 9578       False  False  ...  False    False    False        False  False
# 9579       False  False  ...  False    False    False        False  False
# 9580       False  False  ...  False    False    False        False  False
# 9581       False  False  ...  False    False    False        False  False
#
#       Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 0         False  False   False       False  False
# 1         False  False    True       False  False
# 2         False  False   False        True  False
# 3         False  False   False       False  False
# 4         False  False   False       False  False
# ...         ...    ...     ...         ...    ...
# 9577      False  False   False       False  False
# 9578      False  False   False       False  False
# 9579      False  False   False       False  False
# 9580      False  False   False       False  False
# 9581      False  False   False       False  False
#
# [9535 rows x 46 columns]

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df1[['Age','KmDriven','AskPrice']].corr(),annot=True)
plt.show()

# %%
df_train, df_test = train_test_split(df1, train_size = 0.85, test_size = 0.15, random_state = 1)

# %%
df_train
# Out:
#       Age  KmDriven  AskPrice  Manual  second  Diesel  Hybrid/CNG  Petrol  \
# 482     6    110000   2299000   False   False    True       False   False
# 3864    6    104000    600000    True   False   False        True   False
# 3941    7     76000    549000    True   False   False        True   False
# 2914    7    138000   1900000   False    True    True       False   False
# 2414    2     10000    695000   False   False   False       False    True
# ...   ...       ...       ...     ...     ...     ...         ...     ...
# 2908   14     78000    265000    True    True   False       False    True
# 7849   10     70000    525000   False    True   False       False    True
# 911    10     48000    180000    True    True   False       False    True
# 5216    4     33000   1185000   False   False   False       False    True
# 236     6     39848    479931    True   False   False       False    True
#
#       Ambassador  Ashok  ...   Opel  Porsche  Renault  Rolls-Royce  Skoda  \
# 482        False  False  ...  False    False    False        False  False
# 3864       False  False  ...  False    False    False        False  False
# 3941       False  False  ...  False    False    False        False  False
# 2914       False  False  ...  False    False    False        False   True
# 2414       False  False  ...  False    False     True        False  False
# ...          ...    ...  ...    ...      ...      ...          ...    ...
# 2908       False  False  ...  False    False    False        False  False
# 7849       False  False  ...  False    False    False        False  False
# 911        False  False  ...  False    False    False        False  False
# 5216       False  False  ...  False    False    False        False  False
# 236        False  False  ...  False    False    False        False  False
#
#       Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 482       False  False   False       False  False
# 3864      False  False   False       False  False
# 3941      False  False   False       False  False
# 2914      False  False   False       False  False
# 2414      False  False   False       False  False
# ...         ...    ...     ...         ...    ...
# 2908      False  False   False       False  False
# 7849      False  False   False       False  False
# 911       False   True   False       False  False
# 5216      False  False   False       False  False
# 236       False  False   False       False  False
#
# [8104 rows x 46 columns]

# %%
df_train.shape
# Out:
# (8104, 46)

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train.iloc[:, [i for i in range(df1.shape[1]) if df1.columns[i] != 'AskPrice']]
X_train
# Out:
#       Age  KmDriven  Manual  second  Diesel  Hybrid/CNG  Petrol  Ambassador  \
# 482     6    110000   False   False    True       False   False       False
# 3864    6    104000    True   False   False        True   False       False
# 3941    7     76000    True   False   False        True   False       False
# 2914    7    138000   False    True    True       False   False       False
# 2414    2     10000   False   False   False       False    True       False
# ...   ...       ...     ...     ...     ...         ...     ...         ...
# 2908   14     78000    True    True   False       False    True       False
# 7849   10     70000   False    True   False       False    True       False
# 911    10     48000    True    True   False       False    True       False
# 5216    4     33000   False   False   False       False    True       False
# 236     6     39848    True   False   False       False    True       False
#
#       Ashok  Aston Martin  ...   Opel  Porsche  Renault  Rolls-Royce  Skoda  \
# 482   False         False  ...  False    False    False        False  False
# 3864  False         False  ...  False    False    False        False  False
# 3941  False         False  ...  False    False    False        False  False
# 2914  False         False  ...  False    False    False        False   True
# 2414  False         False  ...  False    False     True        False  False
# ...     ...           ...  ...    ...      ...      ...          ...    ...
# 2908  False         False  ...  False    False    False        False  False
# 7849  False         False  ...  False    False    False        False  False
# 911   False         False  ...  False    False    False        False  False
# 5216  False         False  ...  False    False    False        False  False
# 236   False         False  ...  False    False    False        False  False
#
#       Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 482       False  False   False       False  False
# 3864      False  False   False       False  False
# 3941      False  False   False       False  False
# 2914      False  False   False       False  False
# 2414      False  False   False       False  False
# ...         ...    ...     ...         ...    ...
# 2908      False  False   False       False  False
# 7849      False  False   False       False  False
# 911       False   True   False       False  False
# 5216      False  False   False       False  False
# 236       False  False   False       False  False
#
# [8104 rows x 45 columns]

# %%
Y_train=df_train['AskPrice']
Y_train
# Out:
# 482     2299000
# 3864     600000
# 3941     549000
# 2914    1900000
# 2414     695000
#          ...
# 2908     265000
# 7849     525000
# 911      180000
# 5216    1185000
# 236      479931
# Name: AskPrice, Length: 8104, dtype: int32

# %%
import pickle as pk
filename = 'model.pickle'
pk.dump(lr_model, open(filename, 'wb'))

# %%
lr=LinearRegression()
lr_model=lr.fit(X_train,Y_train)

# %%
data=df1.iloc[100:101]
data
# Out:
#      Age  KmDriven  AskPrice  Manual  second  Diesel  Hybrid/CNG  Petrol  \
# 100    4     59000    980000   False   False   False       False    True
#
#      Ambassador  Ashok  ...   Opel  Porsche  Renault  Rolls-Royce  Skoda  \
# 100       False  False  ...  False    False    False        False  False
#
#      Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 100      False  False   False       False  False
#
# [1 rows x 46 columns]

# %%
actual_askPrice=data['AskPrice']
data=data.drop(['AskPrice'],axis=1)
data
# Out:
#      Age  KmDriven  Manual  second  Diesel  Hybrid/CNG  Petrol  Ambassador  \
# 100    4     59000   False   False   False       False    True       False
#
#      Ashok  Aston Martin  ...   Opel  Porsche  Renault  Rolls-Royce  Skoda  \
# 100  False         False  ...  False    False    False        False  False
#
#      Ssangyong   Tata  Toyota  Volkswagen  Volvo
# 100      False  False   False       False  False
#
# [1 rows x 45 columns]

# %%
print("Predicted Ask Price",lr_model.predict(data))
print("Actual Price",actual_askPrice)
# Out:
# Predicted Ask Price [1108761.37123372]
# Actual Price 100    980000
# Name: AskPrice, dtype: int32

# %%
# # First cell - Import and define attributes
# import pandas as pd

# attributes = {
#     'numeric': ['Age', 'KmDriven'],
#     'binary': ['Manual', 'second', 'Diesel', 'Hybrid/CNG', 'Petrol'],
#     'brands': ['Honda', 'Toyota', 'Volkswagen', 'Maruti Suzuki', 'BMW', 'Ford', 'Kia',
#                'Mercedes-Benz', 'Hyundai', 'Audi', 'Renault', 'MG', 'Volvo', 'Skoda', 'Tata',
#                'Mahindra', 'Mini', 'Land Rover', 'Jeep', 'Chevrolet', 'Jaguar', 'Fiat',
#                'Aston Martin', 'Porsche', 'Nissan', 'Force', 'Mitsubishi', 'Lexus', 'Isuzu',
#                'Datsun', 'Ambassador', 'Rolls-Royce', 'Bajaj', 'Opel', 'Ashok', 'Bentley',
#                'Ssangyong', 'Maserati']
# }

# # Second cell - Helper functions
# def validate_numeric(value, field):
#     """Validate numeric inputs with field-specific rules."""
#     try:
#         value = float(value)
#         if field == 'Age':
#             if value < 0 or value > 50:
#                 raise ValueError("Age must be between 0 and 50 years")
#         elif field == 'KmDriven':
#             if value < 0:
#                 raise ValueError("KmDriven cannot be negative")
       
#         return value
#     except ValueError as e:
#         if str(e).startswith("Age") or str(e).startswith("KmDriven"):
#             raise
#         raise ValueError("Please enter a valid number")

# def get_numeric_input(prompt, field):
#     """Get and validate numeric input."""
#     while True:
#         try:
#             value = input(prompt)
#             return validate_numeric(value, field)
#         except ValueError as e:
#             print(f"Error: {str(e)}")

# def get_car_condition():
#     """Get whether the car is new or second-hand."""
#     while True:
#         condition = input("Is the car new or second-hand? (new/second): ").lower()
#         if condition in ['new', 'second']:
#             return 1 if condition == 'second' else 0
#         print("Please enter either 'new' or 'second'")

# def get_transmission():
#     """Get transmission type."""
#     while True:
#         transmission = input("Enter transmission type (manual/automatic): ").lower()
#         if transmission in ['manual', 'automatic']:
#             return 1 if transmission == 'manual' else 0
#         print("Please enter either 'manual' or 'automatic'")

# def get_fuel_type():
#     """Get fuel type with mutual exclusivity."""
#     print("\nFuel Types:")
#     print("1. Petrol")
#     print("2. Diesel")
#     print("3. Hybrid/CNG")
#     while True:
#         choice = input("Select fuel type (1-3): ")
#         if choice in ['1', '2', '3']:
#             return {
#                 '1': {'Petrol': 1, 'Diesel': 0, 'Hybrid/CNG': 0},
#                 '2': {'Petrol': 0, 'Diesel': 1, 'Hybrid/CNG': 0},
#                 '3': {'Petrol': 0, 'Diesel': 0, 'Hybrid/CNG': 1}
#             }[choice]
#         print("Please select a valid option (1-3)")

# def get_brand(brands):
#     """Get car brand from list."""
#     print("\nAvailable Brands:")
#     for i, brand in enumerate(brands, 1):
#         print(f"{i}. {brand}")
#     while True:
#         try:
#             choice = int(input(f"Select brand (1-{len(brands)}): "))
#             if 1 <= choice <= len(brands):
#                 selected_brand = brands[choice-1]
#                 return {brand: 1 if brand == selected_brand else 0 for brand in brands}
#             print(f"Please enter a number between 1 and {len(brands)}")
#         except ValueError:
#             print("Please enter a valid number")

# # Third cell - Data collection function
# def collect_car_data():
#     data = {}
    
#     # Collect numeric inputs
#     print("=== Numeric Information ===")
#     for attr in attributes['numeric']:
#         data[attr] = [get_numeric_input(f"Enter {attr}: ", attr)]
    
#     # Get car condition
#     print("\n=== Car Condition ===")
#     data['second'] = [get_car_condition()]
    
#     # Get transmission
#     print("\n=== Transmission ===")
#     data['Manual'] = [get_transmission()]
    
#     # Get fuel type
#     print("\n=== Fuel Type ===")
#     fuel_data = get_fuel_type()
#     for fuel_type, value in fuel_data.items():
#         data[fuel_type] = [value]
    
#     # Get brand
#     print("\n=== Brand Selection ===")
#     brand_data = get_brand(attributes['brands'])
#     data.update({brand: [value] for brand, value in brand_data.items()})
    
#     df = pd.DataFrame(data)
    
#     # Define the expected column order based on the training data
#     expected_columns = ['Age', 'KmDriven', 'Manual', 'second', 'Diesel', 'Hybrid/CNG', 
#                        'Petrol', 'Ambassador', 'Ashok', 'Aston Martin', 'Audi', 'BMW',
#                        'Bajaj', 'Bentley', 'Chevrolet', 'Datsun', 'Fiat', 'Force',
#                        'Ford', 'Honda', 'Hyundai', 'Isuzu', 'Jaguar', 'Jeep', 'Kia',
#                        'Land Rover', 'Lexus', 'MG', 'Mahindra', 'Maruti Suzuki',
#                        'Maserati', 'Mercedes-Benz', 'Mini', 'Mitsubishi', 'Nissan',
#                        'Opel', 'Porsche', 'Renault', 'Rolls-Royce', 'Skoda', 
#                        'Ssangyong', 'Tata', 'Toyota', 'Volkswagen', 'Volvo']
    
#     # Reorder columns to match training data
#     df = df.reindex(columns=expected_columns, fill_value=0)
    
#     return df



# working_df = collect_car_data()
# print("\nCollected Data:")
# display(working_df)

# %%
working_df=pd.DataFrame(data)
predicted_value = lr_model.predict(working_df)
print("Predicted value is:", np.round(predicted_value, 2))
print(predicted_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 working_df=pd.DataFrame(data)
#       2 predicted_value = lr_model.predict(working_df)
#       3 print("Predicted value is:", np.round(predicted_value, 2))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
print("Linear regression = ",round(lr_model.score(X_train, Y_train)*100))
# Out:
# Linear regression =  53
